# %% [markdown]
# # Computational Text Analysis
#
# This notebook, created for SICSS 2025 by Björn Ross and based on earlier notebooks by Björn Ross and Steve Wilson, illustrates some common use cases for computational text analysis:
# - Unsupervised learning, using Latent Dirichlet Allocation
# - Supervised learning where a custom classifier (SVM or Random Forest) is trained from scratch
# - Zero-shot learning, where we prompt an LLM (Gemini) to return classification results

# %% [markdown]
# ## Installing and importing packages

# %%
# !pip install gensim
# !pip install pyLDAvis
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.11/dist-packages (4.3.3)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in /usr/local/lib/python3.11/dist-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from gensim) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.11/dist-packages (from gensim) (7.1.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open>=1.8.1->gensim) (1.17.2)
# Requirement already satisfied: pyLDAvis in /usr/local/lib/python3.11/dist-packages (3.4.1)
# Requirement already satisfied: numpy>=1.24.2 in /usr/local/lib/python3.11/dist-packages (from pyLDAvis) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from pyLDAvis) (1.13.1)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from pyLDAvis) (2.2.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from pyLDAvis) (1.5.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from pyLDAvis) (3.1.6)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.11/dist-packages (from pyLDAvis) (2.10.2)
# Requirement already satisfied: funcy in /usr/local/lib/python3.11/dist-packages (from pyLDAvis) (2.0)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from pyLDAvis) (1.6.1)
# Requirement already satisfied: gensim in /usr/local/lib/python3.11/dist-packages (from pyLDAvis) (4.3.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from pyLDAvis) (75.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0.0->pyLDAvis) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0.0->pyLDAvis) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0.0->pyLDAvis) (2025.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.0.0->pyLDAvis) (3.6.0)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.11/dist-packages (from gensim->pyLDAvis) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->pyLDAvis) (3.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->pyLDAvis) (1.17.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open>=1.8.1->gensim->pyLDAvis) (1.17.2)

# %%
import csv
import numpy as np
import pandas as pd
import gensim

import re
import string

from gensim.test.utils import common_texts
from gensim.corpora.dictionary import Dictionary
from gensim.models import LdaModel

from collections import Counter
from scipy import sparse

from sklearn import svm
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier

import pyLDAvis.gensim_models

from tqdm import tqdm
import time

from google.genai import errors

# %% [markdown]
# At this point I sometimes get an error message that can be fixed by restarting the session (Runtime - Restart session).

# %%
import nltk
from nltk.tokenize import word_tokenize

# Download tokenizer data (run once)
nltk.download('punkt_tab')

from nltk.tokenize import TweetTokenizer
tweet_tokenizer = TweetTokenizer()

from nltk.corpus import stopwords

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %% [markdown]
# ## Opening the data

# %%
# check out the data (use ! for command line operation, as opposed to Python code)
# !cat Tweets.14cat.train | head -5
# Out:
# 45029314109075046	Furniture for - so cute! gotta show my #granddog mama the last one especially :) http://t.co/F69aT71TVQ http://t.co/YQVK09pZzB	Pets & Animals
# 45033090867215155	"#Sunday aww"": Mr Peebles	Pets & Animals
# 45036625162627481	CATS ART http://t.co/cJre1jn2Bl #creative #feline #art #love #cat #cats #kittens #housecat #domestic #alley #tomcat	Pets & Animals
# 45086603513077350	RT @Masala_chaai: Keep Calm & Hug your Dog ! #PetLovers cc @MyICETag @pooja330 @huftindia @PranitaBalar @BarknBond http://t.co/JJHSvf…	Pets & Animals
# 45138968053405286	RT @TheSoulfulEMU: RETWEET if you love your dog!! http://t.co/QWvjFFnfiP via @earthposts @LUKIKA 	Pets & Animals

# %%
# Load the data into pandas
training_data = pd.read_csv(
    'Tweets.14cat.train',
    sep='\t',
    quoting = csv.QUOTE_NONE,
    names = ["ID", "Text", "Category"])
training_data
# Out:
#                       ID                                               Text  \
# 0      45029314109075046  Furniture for - so cute! gotta show my #grandd...
# 1      45033090867215155                         "#Sunday aww"": Mr Peebles
# 2      45036625162627481  CATS ART http://t.co/cJre1jn2Bl #creative #fel...
# 3      45086603513077350  RT @Masala_chaai: Keep Calm & Hug your Dog ! #...
# 4      45138968053405286  RT @TheSoulfulEMU: RETWEET if you love your do...
# ...                  ...                                                ...
# 2498  551069446257655808  Series of Car Window Breakages Under Investiga...
# 2499  551156371031199744   night Maltese club offer Evans contract: Conv...
# 2500  551166096598781952  All of today's news headlines in one place. ht...
# 2501  551617864805781504  ISBPL: Affordable housing scheme for EPFO subs...
# 2502  551831514485231616   Police hunt hotel murder suspect: Police have...
#
#              Category
# 0      Pets & Animals
# 1      Pets & Animals
# 2      Pets & Animals
# 3      Pets & Animals
# 4      Pets & Animals
# ...               ...
# 2498  News & Politics
# 2499  News & Politics
# 2500  News & Politics
# 2501  News & Politics
# 2502  News & Politics
#
# [2503 rows x 3 columns]

# %%
test_data = pd.read_csv(
    'Tweets.14cat.test',
    sep='\t',
    quoting = csv.QUOTE_NONE,
    names = ["ID", "Text", "Category"])
test_data
# Out:
#                      ID                                               Text  \
# 0     45108992991784550  21 Photos of Babies and Pets Being the Cutest ...
# 1     45034300968799027  #Trance #House #Electro Masoud feat. Alexandra...
# 2     45077420496768205  Murder trial begins in Fulton County: The tria...
# 3     45056046598311116  Carcraft announces management buyout: CARCRAFT...
# 4     45134816305232691  RT @bill_nizzle: Check out these videos about ...
# ..                  ...                                                ...
# 620  547624232331395072  French feminists place warnings on toys deemed...
# 621  548619949116121088  A Few Thoughts on Reducing Unforced Errors: Th...
# 622  549374461208956928  RT @SriLankaTweet: Tamil National Alliance #TN...
# 623  549823135705362432  Michael Grimm to resign from Congress: sources...
# 624  551075721180106752   for @srvtyagi: Reliance Industries to close N...
#
#                  Category
# 0          Pets & Animals
# 1                   Music
# 2         News & Politics
# 3        Autos & Vehicles
# 4    Science & Technology
# ..                    ...
# 620       News & Politics
# 621       News & Politics
# 622       News & Politics
# 623       News & Politics
# 624       News & Politics
#
# [625 rows x 3 columns]

# %% [markdown]
# ## Latent Dirichlet Allocation for Topic Modelling

# %%
# Tokenize texts
texts = []
for text in training_data["Text"]:
  tokens = tweet_tokenizer.tokenize(text.lower())

  stop_words = set(stopwords.words('english'))
  tokens = [token for token in tokens if token not in stop_words and len(token) > 2]

  texts.append(tokens)

# %%
word_tokenize(training_data["Text"][1])
# Out:
# ['``', '#', 'Sunday', 'aww', "''", "''", ':', 'Mr', 'Peebles']

# %%
tweet_tokenizer.tokenize(training_data["Text"][0])
# Out:
# ['Furniture', 'for', '-', 'so', 'cute', '!', 'gotta', 'show', 'my', '#granddog', 'mama', 'the', 'last', 'one', 'especially', ':)', 'http://t.co/F69aT71TVQ', 'http://t.co/YQVK09pZzB']

# %%
texts[0]
# Out:
# ['furniture', 'cute', 'gotta', 'show', '#granddog', 'mama', 'last', 'one', 'especially', 'http://t.co/f69at71tvq', 'http://t.co/yqvk09pzzb']

# %%
# Create a corpus from a list of texts
common_dictionary = Dictionary(texts)
common_corpus = [common_dictionary.doc2bow(text) for text in texts]

# Train the model on the corpus.

lda = LdaModel(common_corpus,
               num_topics = 10,
               passes = 10,
               iterations = 1000)
# Out:
# WARNING:gensim.models.ldamodel:no word id mapping provided; initializing from corpus, assuming identity

# %%
lda.get_document_topics(bow = common_corpus)

# %%
lda.print_topics()
# Out:
# [(0, '0.012*"71" + 0.009*"5766" + 0.008*"234" + 0.006*"46" + 0.005*"1122" + 0.004*"5623" + 0.004*"593" + 0.004*"5263" + 0.004*"1915" + 0.003*"1127"'), (1, '0.010*"71" + 0.006*"234" + 0.004*"1328" + 0.004*"8603" + 0.004*"62" + 0.003*"740" + 0.003*"1585" + 0.003*"692" + 0.003*"5056" + 0.003*"1401"'), (2, '0.022*"71" + 0.006*"5438" + 0.005*"413" + 0.005*"9" + 0.005*"8513" + 0.004*"1122" + 0.004*"181" + 0.004*"461" + 0.004*"839" + 0.003*"11360"'), (3, '0.020*"71" + 0.006*"646" + 0.005*"593" + 0.005*"1122" + 0.005*"938" + 0.004*"436" + 0.004*"1466" + 0.003*"11099" + 0.003*"815" + 0.003*"234"'), (4, '0.022*"71" + 0.015*"234" + 0.012*"1485" + 0.012*"1122" + 0.007*"1484" + 0.007*"2199" + 0.004*"4576" + 0.004*"1029" + 0.004*"1907" + 0.003*"23"'), (5, '0.006*"46" + 0.005*"815" + 0.005*"1371" + 0.004*"71" + 0.003*"813" + 0.003*"334" + 0.003*"1122" + 0.003*"7336" + 0.003*"9" + 0.003*"953"'), (6, '0.007*"1122" + 0.006*"5097" + 0.004*"62" + 0.004*"577" + 0.003*"46" + 0.003*"329" + 0.003*"7382" + 0.003*"306" + 0.003*"5517" + 0.003*"571"'), (7, '0.017*"71" + 0.007*"234" + 0.005*"536" + 0.005*"46" + 0.004*"3154" + 0.004*"3557" + 0.004*"815" + 0.003*"9" + 0.003*"1347" + 0.003*"304"'), (8, '0.011*"71" + 0.007*"1371" + 0.006*"4052" + 0.004*"580" + 0.004*"1832" + 0.004*"1787" + 0.004*"894" + 0.003*"6437" + 0.003*"5568" + 0.003*"234"'), (9, '0.015*"1122" + 0.011*"71" + 0.005*"3698" + 0.005*"958" + 0.004*"1181" + 0.003*"566" + 0.003*"1882" + 0.003*"5316" + 0.003*"1904" + 0.003*"593"')]

# %%
lda[common_corpus]

# %%
pyLDAvis.enable_notebook()

# %%
panel = pyLDAvis.gensim_models.prepare(lda, corpus = common_corpus, dictionary = common_dictionary)
panel
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 3     -0.171938  0.006504       1        1  12.669031
# 2     -0.091650 -0.162353       2        1  11.939743
# 4     -0.047425  0.155544       3        1  10.759128
# 8      0.071405 -0.056402       4        1   9.994602
# 7      0.063143 -0.009531       5        1   9.587302
# 5      0.056807 -0.014152       6        1   9.509240
# 0      0.016082  0.021543       7        1   9.294240
# 1      0.052173  0.001202       8        1   9.268042
# 9     -0.018231  0.061169       9        1   9.016805
# 6      0.069635 -0.003525      10        1   7.961868, topic_info=          Term        Freq       Total Category  logprob  loglift
# 1485      song   33.000000   33.000000  Default  30.0000  30.0000
# 71         ...  354.000000  354.000000  Default  29.0000  29.0000
# 5766     dress   22.000000   22.000000  Default  28.0000  28.0000
# 1122  #fashion  142.000000  142.000000  Default  27.0000  27.0000
# 1484    posted   19.000000   19.000000  Default  26.0000  26.0000
# ...        ...         ...         ...      ...      ...      ...
# 2781    league    4.297820   13.580441  Topic10  -6.1652   1.3800
# 1843       #rt    4.173770   13.888766  Topic10  -6.1945   1.3282
# 1023      #usa    4.141258   19.672030  Topic10  -6.2023   0.9723
# 234        new    4.264342  128.344590  Topic10  -6.1730  -0.8739
# 958      black    4.142890   34.074212  Topic10  -6.2019   0.4234
#
# [540 rows x 6 columns], token_table=       Topic      Freq        Term
# term
# 413        2  0.838256      #apple
# 413        4  0.157173      #apple
# 1597      10  0.941470  #athletics
# 10927      1  0.822395  #barcelona
# 3089       9  0.895320   #baseball
# ...      ...       ...         ...
# 1158       1  0.372192        year
# 1158       2  0.053170        year
# 1158       6  0.106341        year
# 1158       7  0.319022        year
# 1158       8  0.159511        year
#
# [802 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[4, 3, 5, 9, 8, 6, 1, 2, 10, 7])

# %% [markdown]
# ## Supervised learning-based text classification

# %% [markdown]
# ### Preprocessing the training data for classification

# %%
# convert to list of lists: documents containing tokens
# and return the list of categories
# also get the vocabulary
def preprocess_data(data):

    chars_to_remove = re.compile(f'[{string.punctuation}]')

    documents = []
    categories = []
    vocab = set([])


    for index, row in data.iterrows():
      words = tweet_tokenizer.tokenize(row["Text"].lower())
      for word in words:
        vocab.add(word)

      # add the list of words to the documents list
      documents.append(words)

      # add the category to the categories list
      categories.append(row["Category"])

    return documents, categories, vocab

# %%
# %time
# ^ see how long this takes
# preprocess the data
preprocessed_training_data, training_categories, train_vocab = preprocess_data(training_data)
preprocessed_test_data, test_categories, test_vocab = preprocess_data(test_data)

print(f"Training Data has {len(preprocessed_training_data)} " +
      f"documents and vocab size of {len(train_vocab)}")
print(f"Test Data has {len(preprocessed_test_data)} " +
      f"documents and vocab size of {len(test_vocab)}")
print(f"There were {len(set(training_categories))} " +
      f"categories in the training data and {len(set(test_categories))} in the test.")
# Out:
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 23.1 µs
# Training Data has 2503 documents and vocab size of 13763
# Test Data has 625 documents and vocab size of 4687
# There were 14 categories in the training data and 14 in the test.

# %%
training_categories
# Out:
# ['Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Comedy',
#  'Autos & Vehicles',
#  'Science & Technology',
#  'News & Politics',
#  'News & Politics',
#  'Gaming',
#  'Autos & Vehicles',
#  'Nonprofits & Activism',
#  'Autos & Vehicles',
#  'Music',
#  'Gaming',
#  'Science & Technology',
#  'Science & Technology',
#  'Autos & Vehicles',
#  'Comedy',
#  'Gaming',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Gaming',
#  'News & Politics',
#  'News & Politics',
#  'News & Politics',
#  'Comedy',
#  'Comedy',
#  'Gaming',
#  'Film & Animation',
#  'Film & Animation',
#  'Film & Animation',
#  'Film & Animation',
#  'Film & Animation',
#  'Film & Animation',
#  'Film & Animation',
#  'Film & Animation',
#  'Film & Animation',
#  'Film & Animation',
#  'Comedy',
#  'Gaming',
#  'Science & Technology',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Pets & Animals',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Music',
#  'Autos & Vehicles',
#  'News & Politics',
#  'Autos & Vehicles',
#  'News & Politics',
#  'Travel & Events',
#  'Autos & Vehicles',
#  'Music',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Travel & Events',
#  'News & Politics',
#  'Travel & Events',
#  'Gaming',
#  'News & Politics',
#  'Pets & Animals',
#  'Science & Technology',
#  'Travel & Events',
#  'News & Politics',
#  'News & Politics',
#  'News & Politics',
#  'Gaming',
#  'Entertainment',
#  'Gaming',
#  'Nonprofits & Activism',
#  'Science & Technology',
#  'Education',
#  'Travel & Events',
#  'Gaming',
#  'Gaming',
#  'News & Politics',
#  'News & Politics',
#  'News & Politics',
#  'News & Politics',
#  'Science & Technology',
#  'Education',
#  'Sports',
#  'Music',
#  'Science & Technology',
#  'Sports',
#  'Pets & Animals',
#  'Music',
#  'Music',
#  'Music',
#  'Film & Animation',
#  'Entertainment',
#  'Science & Technology',
#  'Film & Animation',
#  'Film & Animation',
#  'Film & Animation',
#  'Education',
#  'Entertainment',
#  'Science & Technology',
#  'Comedy',
#  'Pets & Animals',
#  'Gaming',
#  'Gaming',
#  'Autos & Vehicles',
#  'Nonprofits & Activism',
#  'Nonprofits & Activism',
#  'Travel & Events',
#  'Film & Animation',
#  'Film & Animation',
#  'Film & Animation',
#  'Film & Animation',
#  'Film & Animation',
#  'Comedy',
#  'Entertainment',
#  'Gaming',
#  'Gaming',
#  'Howto & Style',
#  'Education',
#  'Howto & Style',
#  'Comedy',
#  'Education',
#  'Music',
#  'Music',
#  'Music',
#  'Comedy',
#  'Howto & Style',
#  'Howto & Style',
#  'Autos & Vehicles',
#  'News & Politics',
#  'Howto & Style',
#  'Sports',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Education',
#  'Education',
#  'Sports',
#  'Music',
#  'Music',
#  'Autos & Vehicles',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Education',
#  'Travel & Events',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Howto & Style',
#  'Gaming',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Autos & Vehicles',
#  'Pets & Animals',
#  'Gaming',
#  'Film & Animation',
#  'Howto & Style',
#  'Sports',
#  'Music',
#  'Travel & Events',
#  'Howto & Style',
#  'Music',
#  'Travel & Events',
#  'Nonprofits & Activism',
#  'Pets & Animals',
#  'Howto & Style',
#  'News & Politics',
#  'Pets & Animals',
#  'Nonprofits & Activism',
#  'Gaming',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Gaming',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Travel & Events',
#  'Travel & Events',
#  'Travel & Events',
#  'Travel & Events',
#  'Travel & Events',
#  'Gaming',
#  'Film & Animation',
#  'Travel & Events',
#  'Travel & Events',
#  'Travel & Events',
#  'Pets & Animals',
#  'Music',
#  'Autos & Vehicles',
#  'Howto & Style',
#  'Pets & Animals',
#  'News & Politics',
#  'Education',
#  'Howto & Style',
#  'Howto & Style',
#  'Pets & Animals',
#  'Education',
#  'Howto & Style',
#  'Music',
#  'Travel & Events',
#  'Education',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'News & Politics',
#  'Gaming',
#  'Howto & Style',
#  'Howto & Style',
#  'Howto & Style',
#  'Howto & Style',
#  'Howto & Style',
#  'Howto & Style',
#  'Howto & Style',
#  'Howto & Style',
#  'Howto & Style',
#  'Howto & Style',
#  'Howto & Style',
#  'Howto & Style',
#  'Howto & Style',
#  'Howto & Style',
#  'Howto & Style',
#  'Howto & Style',
#  'Howto & Style',
#  'Howto & Style',
#  'Howto & Style',
#  'Howto & Style',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Music',
#  'Travel & Events',
#  'Travel & Events',
#  'Music',
#  'Music',
#  'Music',
#  'Music',
#  'Music',
#  'Music',
#  'Music',
#  'Music',
#  'Science & Technology',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Entertainment',
#  'Comedy',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Science & Technology',
#  'Nonprofits & Activism',
#  'Nonprofits & Activism',
#  'Nonprofits & Activism',
#  'Nonprofits & Activism',
#  'Entertainment',
#  'Comedy',
#  'Travel & Events',
#  'Travel & Events',
#  'Entertainment',
#  'Entertainment',
#  'Autos & Vehicles',
#  'Comedy',
#  'Autos & Vehicles',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Comedy',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Entertainment',
#  'Film & Animation',
#  'Film & Animation',
#  'Film & Animation',
#  'Film & Animation',
#  'Film & Animation',
#  'Film & Animation',
#  'Film & Animation',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Science & Technology',
#  'Education',
#  'Science & Technology',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Science & Technology',
#  'Comedy',
#  'Science & Technology',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Entertainment',
#  'Travel & Events',
#  'Nonprofits & Activism',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Nonprofits & Activism',
#  'Gaming',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Howto & Style',
#  'Travel & Events',
#  'Science & Technology',
#  'Autos & Vehicles',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Travel & Events',
#  'Science & Technology',
#  'Science & Technology',
#  'Autos & Vehicles',
#  'Howto & Style',
#  'Howto & Style',
#  'Autos & Vehicles',
#  'Comedy',
#  'Gaming',
#  'Gaming',
#  'Comedy',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Gaming',
#  'Music',
#  'Sports',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Sports',
#  'Travel & Events',
#  'Travel & Events',
#  'Howto & Style',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Nonprofits & Activism',
#  'Howto & Style',
#  'Autos & Vehicles',
#  'Nonprofits & Activism',
#  'Howto & Style',
#  'Howto & Style',
#  'Howto & Style',
#  'Music',
#  'Nonprofits & Activism',
#  'Music',
#  'Autos & Vehicles',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Comedy',
#  'Nonprofits & Activism',
#  'Howto & Style',
#  'Music',
#  'Music',
#  'Music',
#  'Music',
#  'Music',
#  'Howto & Style',
#  'Howto & Style',
#  'Howto & Style',
#  'Howto & Style',
#  'Science & Technology',
#  'Sports',
#  'Sports',
#  'Science & Technology',
#  'Comedy',
#  'Autos & Vehicles',
#  'Comedy',
#  'Film & Animation',
#  'Travel & Events',
#  'Autos & Vehicles',
#  'Travel & Events',
#  'Travel & Events',
#  'Travel & Events',
#  'Travel & Events',
#  'Travel & Events',
#  'Travel & Events',
#  'Travel & Events',
#  'Sports',
#  'Autos & Vehicles',
#  'News & Politics',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Nonprofits & Activism',
#  'Nonprofits & Activism',
#  'Nonprofits & Activism',
#  'Autos & Vehicles',
#  'Comedy',
#  'Entertainment',
#  'Film & Animation',
#  'Entertainment',
#  'Science & Technology',
#  'Pets & Animals',
#  'Entertainment',
#  'Science & Technology',
#  'Autos & Vehicles',
#  'Entertainment',
#  'News & Politics',
#  'Entertainment',
#  'News & Politics',
#  'Entertainment',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Entertainment',
#  'Gaming',
#  'Education',
#  'Education',
#  'Pets & Animals',
#  'Film & Animation',
#  'Film & Animation',
#  'Comedy',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Music',
#  'Nonprofits & Activism',
#  'Film & Animation',
#  'Sports',
#  'Music',
#  'Autos & Vehicles',
#  'Comedy',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Science & Technology',
#  'Howto & Style',
#  'Pets & Animals',
#  'Howto & Style',
#  'News & Politics',
#  'News & Politics',
#  'News & Politics',
#  'News & Politics',
#  'Howto & Style',
#  'Education',
#  'Travel & Events',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Nonprofits & Activism',
#  'Howto & Style',
#  'Nonprofits & Activism',
#  'Howto & Style',
#  'Music',
#  'Howto & Style',
#  'Science & Technology',
#  'Pets & Animals',
#  'Comedy',
#  'Autos & Vehicles',
#  'Science & Technology',
#  'Science & Technology',
#  'Howto & Style',
#  'Education',
#  'Science & Technology',
#  'Film & Animation',
#  'Film & Animation',
#  'Film & Animation',
#  'Pets & Animals',
#  'Science & Technology',
#  'Howto & Style',
#  'Pets & Animals',
#  'Music',
#  'Autos & Vehicles',
#  'Comedy',
#  'Autos & Vehicles',
#  'Pets & Animals',
#  'Travel & Events',
#  'Travel & Events',
#  'Travel & Events',
#  'Comedy',
#  'Comedy',
#  'Travel & Events',
#  'Travel & Events',
#  'Comedy',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Pets & Animals',
#  'Comedy',
#  'Travel & Events',
#  'Travel & Events',
#  'Travel & Events',
#  'Nonprofits & Activism',
#  'Travel & Events',
#  'Film & Animation',
#  'Comedy',
#  'Comedy',
#  'Education',
#  'Travel & Events',
#  'Travel & Events',
#  'Travel & Events',
#  'Pets & Animals',
#  'Nonprofits & Activism',
#  'Nonprofits & Activism',
#  'Nonprofits & Activism',
#  'Science & Technology',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Music',
#  'Travel & Events',
#  'News & Politics',
#  'Comedy',
#  'Comedy',
#  'News & Politics',
#  'Howto & Style',
#  'Film & Animation',
#  'Sports',
#  'Music',
#  'Travel & Events',
#  'News & Politics',
#  'News & Politics',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Film & Animation',
#  'Travel & Events',
#  'Music',
#  'Sports',
#  'Sports',
#  'Howto & Style',
#  'Music',
#  'Howto & Style',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Science & Technology',
#  'Film & Animation',
#  'Nonprofits & Activism',
#  'Nonprofits & Activism',
#  'News & Politics',
#  'Music',
#  'Sports',
#  'Howto & Style',
#  'Entertainment',
#  'News & Politics',
#  'Sports',
#  'Travel & Events',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'News & Politics',
#  'News & Politics',
#  'Entertainment',
#  'Autos & Vehicles',
#  'Entertainment',
#  'News & Politics',
#  'News & Politics',
#  'News & Politics',
#  'News & Politics',
#  'News & Politics',
#  'News & Politics',
#  'News & Politics',
#  'Music',
#  'Howto & Style',
#  'Travel & Events',
#  'Travel & Events',
#  'Travel & Events',
#  'Travel & Events',
#  'Travel & Events',
#  'Science & Technology',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Comedy',
#  'Nonprofits & Activism',
#  'Film & Animation',
#  'Entertainment',
#  'Science & Technology',
#  'Comedy',
#  'Film & Animation',
#  'Film & Animation',
#  'Entertainment',
#  'Howto & Style',
#  'Education',
#  'News & Politics',
#  'Science & Technology',
#  'Science & Technology',
#  'Science & Technology',
#  'Education',
#  'Howto & Style',
#  'Entertainment',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Howto & Style',
#  'Comedy',
#  'Howto & Style',
#  'Film & Animation',
#  'Howto & Style',
#  'Travel & Events',
#  'Travel & Events',
#  'Travel & Events',
#  'Travel & Events',
#  'Travel & Events',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Film & Animation',
#  'Howto & Style',
#  'Film & Animation',
#  'Nonprofits & Activism',
#  'Nonprofits & Activism',
#  'Nonprofits & Activism',
#  'Nonprofits & Activism',
#  'Science & Technology',
#  'Music',
#  'Film & Animation',
#  'Film & Animation',
#  'Education',
#  'Education',
#  'Education',
#  'Howto & Style',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Entertainment',
#  'Entertainment',
#  'Travel & Events',
#  'Comedy',
#  'Travel & Events',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Travel & Events',
#  'Comedy',
#  'Science & Technology',
#  'Comedy',
#  'Film & Animation',
#  'Howto & Style',
#  'Pets & Animals',
#  'Entertainment',
#  'Science & Technology',
#  'Howto & Style',
#  'News & Politics',
#  'Music',
#  'Travel & Events',
#  'Travel & Events',
#  'Travel & Events',
#  'Pets & Animals',
#  'Howto & Style',
#  'Science & Technology',
#  'Science & Technology',
#  'Science & Technology',
#  'Science & Technology',
#  'Science & Technology',
#  'Science & Technology',
#  'Science & Technology',
#  'News & Politics',
#  'News & Politics',
#  'News & Politics',
#  'News & Politics',
#  'Entertainment',
#  'Pets & Animals',
#  'Nonprofits & Activism',
#  'Education',
#  'Travel & Events',
#  'Film & Animation',
#  'Entertainment',
#  'Comedy',
#  'Entertainment',
#  'Travel & Events',
#  'Comedy',
#  'Film & Animation',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Science & Technology',
#  'Science & Technology',
#  'Science & Technology',
#  'Howto & Style',
#  'Travel & Events',
#  'Travel & Events',
#  'Education',
#  'Entertainment',
#  'Education',
#  'Entertainment',
#  'Entertainment',
#  'Howto & Style',
#  'Travel & Events',
#  'Entertainment',
#  'Comedy',
#  'Travel & Events',
#  'Education',
#  'Comedy',
#  'Autos & Vehicles',
#  'Pets & Animals',
#  'News & Politics',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Comedy',
#  'Travel & Events',
#  'Entertainment',
#  'Howto & Style',
#  'Howto & Style',
#  'Howto & Style',
#  'Howto & Style',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Howto & Style',
#  'Howto & Style',
#  'Howto & Style',
#  'Howto & Style',
#  'Science & Technology',
#  'Comedy',
#  'Travel & Events',
#  'News & Politics',
#  'Nonprofits & Activism',
#  'Film & Animation',
#  'Film & Animation',
#  'Music',
#  'Music',
#  'Science & Technology',
#  'Science & Technology',
#  'Science & Technology',
#  'Entertainment',
#  'Sports',
#  'Entertainment',
#  'Comedy',
#  'Sports',
#  'Sports',
#  'News & Politics',
#  'Travel & Events',
#  'Film & Animation',
#  'Science & Technology',
#  'Entertainment',
#  'Entertainment',
#  'Film & Animation',
#  'Film & Animation',
#  'Film & Animation',
#  'Film & Animation',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Nonprofits & Activism',
#  'Music',
#  'News & Politics',
#  'Gaming',
#  'Nonprofits & Activism',
#  'Nonprofits & Activism',
#  'Nonprofits & Activism',
#  'Music',
#  'News & Politics',
#  'Education',
#  'Music',
#  'Music',
#  'Music',
#  'Music',
#  'Music',
#  'Comedy',
#  'Education',
#  'Education',
#  'Education',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Film & Animation',
#  'Film & Animation',
#  'Nonprofits & Activism',
#  'Comedy',
#  'Nonprofits & Activism',
#  'News & Politics',
#  'News & Politics',
#  'News & Politics',
#  'News & Politics',
#  'News & Politics',
#  'News & Politics',
#  'News & Politics',
#  'News & Politics',
#  'News & Politics',
#  'News & Politics',
#  'News & Politics',
#  'Nonprofits & Activism',
#  'Nonprofits & Activism',
#  'Gaming',
#  'Comedy',
#  'Howto & Style',
#  'Film & Animation',
#  'Film & Animation',
#  'Autos & Vehicles',
#  'Howto & Style',
#  'Comedy',
#  'Comedy',
#  'Howto & Style',
#  'Gaming',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Howto & Style',
#  'Travel & Events',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Gaming',
#  'Gaming',
#  'Science & Technology',
#  'Comedy',
#  'News & Politics',
#  'Gaming',
#  'Science & Technology',
#  'Science & Technology',
#  'Gaming',
#  'Education',
#  'Education',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Howto & Style',
#  'Howto & Style',
#  'Howto & Style',
#  'Gaming',
#  'Gaming',
#  'Travel & Events',
#  'Pets & Animals',
#  'Film & Animation',
#  'Gaming',
#  'Travel & Events',
#  'Pets & Animals',
#  'Film & Animation',
#  'Film & Animation',
#  'Travel & Events',
#  'Film & Animation',
#  'Gaming',
#  'News & Politics',
#  'Gaming',
#  'Entertainment',
#  'Music',
#  'Science & Technology',
#  'News & Politics',
#  'Sports',
#  'Travel & Events',
#  'Travel & Events',
#  'Science & Technology',
#  'Science & Technology',
#  'Entertainment',
#  'Gaming',
#  'Gaming',
#  'Education',
#  'Gaming',
#  ...]

# %%
list(training_data["Category"])
# Out:
# ['Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Comedy',
#  'Autos & Vehicles',
#  'Science & Technology',
#  'News & Politics',
#  'News & Politics',
#  'Gaming',
#  'Autos & Vehicles',
#  'Nonprofits & Activism',
#  'Autos & Vehicles',
#  'Music',
#  'Gaming',
#  'Science & Technology',
#  'Science & Technology',
#  'Autos & Vehicles',
#  'Comedy',
#  'Gaming',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Gaming',
#  'News & Politics',
#  'News & Politics',
#  'News & Politics',
#  'Comedy',
#  'Comedy',
#  'Gaming',
#  'Film & Animation',
#  'Film & Animation',
#  'Film & Animation',
#  'Film & Animation',
#  'Film & Animation',
#  'Film & Animation',
#  'Film & Animation',
#  'Film & Animation',
#  'Film & Animation',
#  'Film & Animation',
#  'Comedy',
#  'Gaming',
#  'Science & Technology',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Pets & Animals',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Music',
#  'Autos & Vehicles',
#  'News & Politics',
#  'Autos & Vehicles',
#  'News & Politics',
#  'Travel & Events',
#  'Autos & Vehicles',
#  'Music',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Travel & Events',
#  'News & Politics',
#  'Travel & Events',
#  'Gaming',
#  'News & Politics',
#  'Pets & Animals',
#  'Science & Technology',
#  'Travel & Events',
#  'News & Politics',
#  'News & Politics',
#  'News & Politics',
#  'Gaming',
#  'Entertainment',
#  'Gaming',
#  'Nonprofits & Activism',
#  'Science & Technology',
#  'Education',
#  'Travel & Events',
#  'Gaming',
#  'Gaming',
#  'News & Politics',
#  'News & Politics',
#  'News & Politics',
#  'News & Politics',
#  'Science & Technology',
#  'Education',
#  'Sports',
#  'Music',
#  'Science & Technology',
#  'Sports',
#  'Pets & Animals',
#  'Music',
#  'Music',
#  'Music',
#  'Film & Animation',
#  'Entertainment',
#  'Science & Technology',
#  'Film & Animation',
#  'Film & Animation',
#  'Film & Animation',
#  'Education',
#  'Entertainment',
#  'Science & Technology',
#  'Comedy',
#  'Pets & Animals',
#  'Gaming',
#  'Gaming',
#  'Autos & Vehicles',
#  'Nonprofits & Activism',
#  'Nonprofits & Activism',
#  'Travel & Events',
#  'Film & Animation',
#  'Film & Animation',
#  'Film & Animation',
#  'Film & Animation',
#  'Film & Animation',
#  'Comedy',
#  'Entertainment',
#  'Gaming',
#  'Gaming',
#  'Howto & Style',
#  'Education',
#  'Howto & Style',
#  'Comedy',
#  'Education',
#  'Music',
#  'Music',
#  'Music',
#  'Comedy',
#  'Howto & Style',
#  'Howto & Style',
#  'Autos & Vehicles',
#  'News & Politics',
#  'Howto & Style',
#  'Sports',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Education',
#  'Education',
#  'Sports',
#  'Music',
#  'Music',
#  'Autos & Vehicles',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Education',
#  'Travel & Events',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Howto & Style',
#  'Gaming',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Autos & Vehicles',
#  'Pets & Animals',
#  'Gaming',
#  'Film & Animation',
#  'Howto & Style',
#  'Sports',
#  'Music',
#  'Travel & Events',
#  'Howto & Style',
#  'Music',
#  'Travel & Events',
#  'Nonprofits & Activism',
#  'Pets & Animals',
#  'Howto & Style',
#  'News & Politics',
#  'Pets & Animals',
#  'Nonprofits & Activism',
#  'Gaming',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Gaming',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Travel & Events',
#  'Travel & Events',
#  'Travel & Events',
#  'Travel & Events',
#  'Travel & Events',
#  'Gaming',
#  'Film & Animation',
#  'Travel & Events',
#  'Travel & Events',
#  'Travel & Events',
#  'Pets & Animals',
#  'Music',
#  'Autos & Vehicles',
#  'Howto & Style',
#  'Pets & Animals',
#  'News & Politics',
#  'Education',
#  'Howto & Style',
#  'Howto & Style',
#  'Pets & Animals',
#  'Education',
#  'Howto & Style',
#  'Music',
#  'Travel & Events',
#  'Education',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'News & Politics',
#  'Gaming',
#  'Howto & Style',
#  'Howto & Style',
#  'Howto & Style',
#  'Howto & Style',
#  'Howto & Style',
#  'Howto & Style',
#  'Howto & Style',
#  'Howto & Style',
#  'Howto & Style',
#  'Howto & Style',
#  'Howto & Style',
#  'Howto & Style',
#  'Howto & Style',
#  'Howto & Style',
#  'Howto & Style',
#  'Howto & Style',
#  'Howto & Style',
#  'Howto & Style',
#  'Howto & Style',
#  'Howto & Style',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Music',
#  'Travel & Events',
#  'Travel & Events',
#  'Music',
#  'Music',
#  'Music',
#  'Music',
#  'Music',
#  'Music',
#  'Music',
#  'Music',
#  'Science & Technology',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Entertainment',
#  'Comedy',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Science & Technology',
#  'Nonprofits & Activism',
#  'Nonprofits & Activism',
#  'Nonprofits & Activism',
#  'Nonprofits & Activism',
#  'Entertainment',
#  'Comedy',
#  'Travel & Events',
#  'Travel & Events',
#  'Entertainment',
#  'Entertainment',
#  'Autos & Vehicles',
#  'Comedy',
#  'Autos & Vehicles',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Comedy',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Entertainment',
#  'Film & Animation',
#  'Film & Animation',
#  'Film & Animation',
#  'Film & Animation',
#  'Film & Animation',
#  'Film & Animation',
#  'Film & Animation',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Science & Technology',
#  'Education',
#  'Science & Technology',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Science & Technology',
#  'Comedy',
#  'Science & Technology',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Entertainment',
#  'Travel & Events',
#  'Nonprofits & Activism',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Nonprofits & Activism',
#  'Gaming',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Howto & Style',
#  'Travel & Events',
#  'Science & Technology',
#  'Autos & Vehicles',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Travel & Events',
#  'Science & Technology',
#  'Science & Technology',
#  'Autos & Vehicles',
#  'Howto & Style',
#  'Howto & Style',
#  'Autos & Vehicles',
#  'Comedy',
#  'Gaming',
#  'Gaming',
#  'Comedy',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Gaming',
#  'Music',
#  'Sports',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Sports',
#  'Travel & Events',
#  'Travel & Events',
#  'Howto & Style',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Nonprofits & Activism',
#  'Howto & Style',
#  'Autos & Vehicles',
#  'Nonprofits & Activism',
#  'Howto & Style',
#  'Howto & Style',
#  'Howto & Style',
#  'Music',
#  'Nonprofits & Activism',
#  'Music',
#  'Autos & Vehicles',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Comedy',
#  'Nonprofits & Activism',
#  'Howto & Style',
#  'Music',
#  'Music',
#  'Music',
#  'Music',
#  'Music',
#  'Howto & Style',
#  'Howto & Style',
#  'Howto & Style',
#  'Howto & Style',
#  'Science & Technology',
#  'Sports',
#  'Sports',
#  'Science & Technology',
#  'Comedy',
#  'Autos & Vehicles',
#  'Comedy',
#  'Film & Animation',
#  'Travel & Events',
#  'Autos & Vehicles',
#  'Travel & Events',
#  'Travel & Events',
#  'Travel & Events',
#  'Travel & Events',
#  'Travel & Events',
#  'Travel & Events',
#  'Travel & Events',
#  'Sports',
#  'Autos & Vehicles',
#  'News & Politics',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Nonprofits & Activism',
#  'Nonprofits & Activism',
#  'Nonprofits & Activism',
#  'Autos & Vehicles',
#  'Comedy',
#  'Entertainment',
#  'Film & Animation',
#  'Entertainment',
#  'Science & Technology',
#  'Pets & Animals',
#  'Entertainment',
#  'Science & Technology',
#  'Autos & Vehicles',
#  'Entertainment',
#  'News & Politics',
#  'Entertainment',
#  'News & Politics',
#  'Entertainment',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Entertainment',
#  'Gaming',
#  'Education',
#  'Education',
#  'Pets & Animals',
#  'Film & Animation',
#  'Film & Animation',
#  'Comedy',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Music',
#  'Nonprofits & Activism',
#  'Film & Animation',
#  'Sports',
#  'Music',
#  'Autos & Vehicles',
#  'Comedy',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Science & Technology',
#  'Howto & Style',
#  'Pets & Animals',
#  'Howto & Style',
#  'News & Politics',
#  'News & Politics',
#  'News & Politics',
#  'News & Politics',
#  'Howto & Style',
#  'Education',
#  'Travel & Events',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Nonprofits & Activism',
#  'Howto & Style',
#  'Nonprofits & Activism',
#  'Howto & Style',
#  'Music',
#  'Howto & Style',
#  'Science & Technology',
#  'Pets & Animals',
#  'Comedy',
#  'Autos & Vehicles',
#  'Science & Technology',
#  'Science & Technology',
#  'Howto & Style',
#  'Education',
#  'Science & Technology',
#  'Film & Animation',
#  'Film & Animation',
#  'Film & Animation',
#  'Pets & Animals',
#  'Science & Technology',
#  'Howto & Style',
#  'Pets & Animals',
#  'Music',
#  'Autos & Vehicles',
#  'Comedy',
#  'Autos & Vehicles',
#  'Pets & Animals',
#  'Travel & Events',
#  'Travel & Events',
#  'Travel & Events',
#  'Comedy',
#  'Comedy',
#  'Travel & Events',
#  'Travel & Events',
#  'Comedy',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Pets & Animals',
#  'Comedy',
#  'Travel & Events',
#  'Travel & Events',
#  'Travel & Events',
#  'Nonprofits & Activism',
#  'Travel & Events',
#  'Film & Animation',
#  'Comedy',
#  'Comedy',
#  'Education',
#  'Travel & Events',
#  'Travel & Events',
#  'Travel & Events',
#  'Pets & Animals',
#  'Nonprofits & Activism',
#  'Nonprofits & Activism',
#  'Nonprofits & Activism',
#  'Science & Technology',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Music',
#  'Travel & Events',
#  'News & Politics',
#  'Comedy',
#  'Comedy',
#  'News & Politics',
#  'Howto & Style',
#  'Film & Animation',
#  'Sports',
#  'Music',
#  'Travel & Events',
#  'News & Politics',
#  'News & Politics',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Film & Animation',
#  'Travel & Events',
#  'Music',
#  'Sports',
#  'Sports',
#  'Howto & Style',
#  'Music',
#  'Howto & Style',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Science & Technology',
#  'Film & Animation',
#  'Nonprofits & Activism',
#  'Nonprofits & Activism',
#  'News & Politics',
#  'Music',
#  'Sports',
#  'Howto & Style',
#  'Entertainment',
#  'News & Politics',
#  'Sports',
#  'Travel & Events',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'News & Politics',
#  'News & Politics',
#  'Entertainment',
#  'Autos & Vehicles',
#  'Entertainment',
#  'News & Politics',
#  'News & Politics',
#  'News & Politics',
#  'News & Politics',
#  'News & Politics',
#  'News & Politics',
#  'News & Politics',
#  'Music',
#  'Howto & Style',
#  'Travel & Events',
#  'Travel & Events',
#  'Travel & Events',
#  'Travel & Events',
#  'Travel & Events',
#  'Science & Technology',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Comedy',
#  'Nonprofits & Activism',
#  'Film & Animation',
#  'Entertainment',
#  'Science & Technology',
#  'Comedy',
#  'Film & Animation',
#  'Film & Animation',
#  'Entertainment',
#  'Howto & Style',
#  'Education',
#  'News & Politics',
#  'Science & Technology',
#  'Science & Technology',
#  'Science & Technology',
#  'Education',
#  'Howto & Style',
#  'Entertainment',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Howto & Style',
#  'Comedy',
#  'Howto & Style',
#  'Film & Animation',
#  'Howto & Style',
#  'Travel & Events',
#  'Travel & Events',
#  'Travel & Events',
#  'Travel & Events',
#  'Travel & Events',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Film & Animation',
#  'Howto & Style',
#  'Film & Animation',
#  'Nonprofits & Activism',
#  'Nonprofits & Activism',
#  'Nonprofits & Activism',
#  'Nonprofits & Activism',
#  'Science & Technology',
#  'Music',
#  'Film & Animation',
#  'Film & Animation',
#  'Education',
#  'Education',
#  'Education',
#  'Howto & Style',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Entertainment',
#  'Entertainment',
#  'Travel & Events',
#  'Comedy',
#  'Travel & Events',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Travel & Events',
#  'Comedy',
#  'Science & Technology',
#  'Comedy',
#  'Film & Animation',
#  'Howto & Style',
#  'Pets & Animals',
#  'Entertainment',
#  'Science & Technology',
#  'Howto & Style',
#  'News & Politics',
#  'Music',
#  'Travel & Events',
#  'Travel & Events',
#  'Travel & Events',
#  'Pets & Animals',
#  'Howto & Style',
#  'Science & Technology',
#  'Science & Technology',
#  'Science & Technology',
#  'Science & Technology',
#  'Science & Technology',
#  'Science & Technology',
#  'Science & Technology',
#  'News & Politics',
#  'News & Politics',
#  'News & Politics',
#  'News & Politics',
#  'Entertainment',
#  'Pets & Animals',
#  'Nonprofits & Activism',
#  'Education',
#  'Travel & Events',
#  'Film & Animation',
#  'Entertainment',
#  'Comedy',
#  'Entertainment',
#  'Travel & Events',
#  'Comedy',
#  'Film & Animation',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Gaming',
#  'Science & Technology',
#  'Science & Technology',
#  'Science & Technology',
#  'Howto & Style',
#  'Travel & Events',
#  'Travel & Events',
#  'Education',
#  'Entertainment',
#  'Education',
#  'Entertainment',
#  'Entertainment',
#  'Howto & Style',
#  'Travel & Events',
#  'Entertainment',
#  'Comedy',
#  'Travel & Events',
#  'Education',
#  'Comedy',
#  'Autos & Vehicles',
#  'Pets & Animals',
#  'News & Politics',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Comedy',
#  'Travel & Events',
#  'Entertainment',
#  'Howto & Style',
#  'Howto & Style',
#  'Howto & Style',
#  'Howto & Style',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Pets & Animals',
#  'Howto & Style',
#  'Howto & Style',
#  'Howto & Style',
#  'Howto & Style',
#  'Science & Technology',
#  'Comedy',
#  'Travel & Events',
#  'News & Politics',
#  'Nonprofits & Activism',
#  'Film & Animation',
#  'Film & Animation',
#  'Music',
#  'Music',
#  'Science & Technology',
#  'Science & Technology',
#  'Science & Technology',
#  'Entertainment',
#  'Sports',
#  'Entertainment',
#  'Comedy',
#  'Sports',
#  'Sports',
#  'News & Politics',
#  'Travel & Events',
#  'Film & Animation',
#  'Science & Technology',
#  'Entertainment',
#  'Entertainment',
#  'Film & Animation',
#  'Film & Animation',
#  'Film & Animation',
#  'Film & Animation',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Nonprofits & Activism',
#  'Music',
#  'News & Politics',
#  'Gaming',
#  'Nonprofits & Activism',
#  'Nonprofits & Activism',
#  'Nonprofits & Activism',
#  'Music',
#  'News & Politics',
#  'Education',
#  'Music',
#  'Music',
#  'Music',
#  'Music',
#  'Music',
#  'Comedy',
#  'Education',
#  'Education',
#  'Education',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Film & Animation',
#  'Film & Animation',
#  'Nonprofits & Activism',
#  'Comedy',
#  'Nonprofits & Activism',
#  'News & Politics',
#  'News & Politics',
#  'News & Politics',
#  'News & Politics',
#  'News & Politics',
#  'News & Politics',
#  'News & Politics',
#  'News & Politics',
#  'News & Politics',
#  'News & Politics',
#  'News & Politics',
#  'Nonprofits & Activism',
#  'Nonprofits & Activism',
#  'Gaming',
#  'Comedy',
#  'Howto & Style',
#  'Film & Animation',
#  'Film & Animation',
#  'Autos & Vehicles',
#  'Howto & Style',
#  'Comedy',
#  'Comedy',
#  'Howto & Style',
#  'Gaming',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Howto & Style',
#  'Travel & Events',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Gaming',
#  'Gaming',
#  'Science & Technology',
#  'Comedy',
#  'News & Politics',
#  'Gaming',
#  'Science & Technology',
#  'Science & Technology',
#  'Gaming',
#  'Education',
#  'Education',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Autos & Vehicles',
#  'Howto & Style',
#  'Howto & Style',
#  'Howto & Style',
#  'Gaming',
#  'Gaming',
#  'Travel & Events',
#  'Pets & Animals',
#  'Film & Animation',
#  'Gaming',
#  'Travel & Events',
#  'Pets & Animals',
#  'Film & Animation',
#  'Film & Animation',
#  'Travel & Events',
#  'Film & Animation',
#  'Gaming',
#  'News & Politics',
#  'Gaming',
#  'Entertainment',
#  'Music',
#  'Science & Technology',
#  'News & Politics',
#  'Sports',
#  'Travel & Events',
#  'Travel & Events',
#  'Science & Technology',
#  'Science & Technology',
#  'Entertainment',
#  'Gaming',
#  'Gaming',
#  'Education',
#  'Gaming',
#  ...]

# %%
# check the most common categories in the training data
print(Counter(training_categories).most_common())
# Out:
# [('Gaming', 220), ('Autos & Vehicles', 210), ('Howto & Style', 207), ('Sports', 203), ('Travel & Events', 196), ('Science & Technology', 189), ('Film & Animation', 178), ('Pets & Animals', 177), ('News & Politics', 168), ('Music', 160), ('Entertainment', 159), ('Comedy', 153), ('Education', 142), ('Nonprofits & Activism', 141)]

# %% [markdown]
# ### Set up mappings for word and category IDs

# %%
# convert the vocab to a word id lookup dictionary
# anything not in this will be considered "out of vocabulary" OOV
word2id = {}
for word_id,word in enumerate(train_vocab):
    word2id[word] = word_id

# and do the same for the categories
cat2id = {}
for cat_id,cat in enumerate(set(training_categories)):
    cat2id[cat] = cat_id

print("The word id for dog is",word2id['dog'])
print("The category id for Pets & Animals is",cat2id['Pets & Animals'])
# Out:
# The word id for dog is 5658
# The category id for Pets & Animals is 4

# %%
cat2id
# Out:
# {'Science & Technology': 0,
#  'News & Politics': 1,
#  'Entertainment': 2,
#  'Film & Animation': 3,
#  'Pets & Animals': 4,
#  'Nonprofits & Activism': 5,
#  'Travel & Events': 6,
#  'Music': 7,
#  'Comedy': 8,
#  'Sports': 9,
#  'Howto & Style': 10,
#  'Education': 11,
#  'Autos & Vehicles': 12,
#  'Gaming': 13}

# %% [markdown]
# ### Convert data to bag-of-words format

# %%
# build a BOW representation of the files: use the scipy
# data is the preprocessed_data
# word2id maps words to their ids
def convert_to_bow_matrix(preprocessed_data, word2id):

    # matrix size is number of docs x vocab size + 1 (for OOV)
    matrix_size = (len(preprocessed_data),len(word2id)+1)
    oov_index = len(word2id)
    # matrix indexed by [doc_id, token_id]
    X = sparse.dok_matrix(matrix_size)

    # iterate through all documents in the dataset
    for doc_id,doc in enumerate(preprocessed_data):
        for word in doc:
            # default is 0, so just add to the count for this word in this doc
            # if the word is oov, increment the oov_index
            X[doc_id,word2id.get(word,oov_index)] += 1

    return X

# %%
# %%time
X_train = convert_to_bow_matrix(preprocessed_training_data, word2id)
# Out:
# CPU times: user 787 ms, sys: 5.32 ms, total: 792 ms
# Wall time: 790 ms

# %%
# check some docs
print("First 3 documents are:",X_train[:3])
# Out:
# First 3 documents are:   (0, 1672)	1.0
#   (0, 11695)	1.0
#   (0, 9080)	1.0
#   (0, 4998)	1.0
#   (0, 10131)	1.0
#   (0, 12237)	1.0
#   (0, 2514)	1.0
#   (0, 10594)	1.0
#   (0, 8593)	1.0
#   (0, 8684)	1.0
#   (0, 13363)	1.0
#   (0, 6420)	1.0
#   (0, 1384)	1.0
#   (0, 4111)	1.0
#   (0, 764)	1.0
#   (0, 7387)	1.0
#   (0, 11272)	1.0
#   (0, 5408)	1.0
#   (1, 8574)	3.0
#   (1, 3738)	1.0
#   (1, 10412)	1.0
#   (1, 4817)	1.0
#   (1, 7006)	1.0
#   (1, 12058)	1.0
#   (2, 8929)	1.0
#   (2, 5424)	1.0
#   (2, 11514)	1.0
#   (2, 8108)	1.0
#   (2, 2775)	1.0
#   (2, 2776)	1.0
#   (2, 5020)	1.0
#   (2, 11305)	1.0
#   (2, 2735)	1.0
#   (2, 12257)	1.0
#   (2, 8330)	1.0
#   (2, 2190)	1.0
#   (2, 6528)	1.0
#   (2, 10097)	1.0

# %%
y_train = [cat2id[cat] for cat in training_categories]

# %%
# check the first 3 categories
print(y_train[:3])
# Out:
# [4, 4, 4]

# %%
X_train
# Out:
# <2503x13764 sparse matrix of type '<class 'numpy.float64'>'
# 	with 38369 stored elements in Dictionary Of Keys format>

# %% [markdown]
# ### Train an SVM model

# %%
# Let's train a model: now that the setup is done, it's a piece of cake!
# %time
# instantiate an SVM classification model
# https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html#sklearn.svm.SVC
# you can set various model hyperparamters here
model = svm.SVC(C=1000, kernel ="linear")
# then train the model!
model.fit(X_train,y_train)
# Out:
# CPU times: user 4 µs, sys: 1 µs, total: 5 µs
# Wall time: 7.15 µs
# SVC(C=1000, kernel='linear')

# %%
# make a prediction
sample_text = ['retweet','if','you','are','a','dog','person']
# create just a single vector as input (as a 1 x V matrix)
sample_x_in = sparse.dok_matrix((1,len(word2id)+1))
for word in sample_text:
    sample_x_in[0,word2id[word]] += 1

# what does the example document look like?
print(sample_x_in)
prediction = model.predict(sample_x_in)
# what category was predicted?
print("Prediction was:",prediction[0])
# what category was that?
print(cat2id)
# Out:
#   (0, 2246)	1.0
#   (0, 11441)	1.0
#   (0, 2902)	1.0
#   (0, 1424)	1.0
#   (0, 3898)	1.0
#   (0, 5658)	1.0
#   (0, 10822)	1.0
# Prediction was: 4
# {'Science & Technology': 0, 'News & Politics': 1, 'Entertainment': 2, 'Film & Animation': 3, 'Pets & Animals': 4, 'Nonprofits & Activism': 5, 'Travel & Events': 6, 'Music': 7, 'Comedy': 8, 'Sports': 9, 'Howto & Style': 10, 'Education': 11, 'Autos & Vehicles': 12, 'Gaming': 13}

# %% [markdown]
# ### Evaluating the model

# %%
# evaluate on training data: how well did we fit to the data we trained on?
y_train_predictions = model.predict(X_train)

# now can compute any metrics we care about. Let's quickly do accuracy
def compute_accuracy(predictions, true_values):
    num_correct = 0
    num_total = len(predictions)
    for predicted,true in zip(predictions,true_values):
        if predicted==true:
            num_correct += 1
    return num_correct / num_total

accuracy = compute_accuracy(y_train_predictions,y_train)
print("Accuracy:",accuracy)
# how did we do?
# Out:
# Accuracy: 1.0

# %% [markdown]
# Is that a good score? The score can be informative, but it isn't hard to do well on the training data.

# %%
# prepare test data in the same was as training data
X_test = convert_to_bow_matrix(preprocessed_test_data, word2id)
y_test = [cat2id[cat] for cat in test_categories]

# %%
# now evaluate on test data: data the model has NOT seen during training time
# make sure you do NOT update the model, only get predictions from it
y_test_predictions = model.predict(X_test)
y_test_predictions
# Out:
# array([ 4,  0,  1, 12,  8,  1, 13,  5,  3,  0,  6,  1,  4,  6, 12,  4,  2,
#         0, 11,  4, 11, 12,  5,  1,  6,  7,  1,  2, 12,  6,  3,  9, 13,  6,
#        10,  6,  7,  8,  8, 12,  6,  4,  1, 11,  0,  5,  0,  9,  4,  0,  6,
#         1,  6,  4, 10, 13,  2,  2,  7, 10, 10, 10, 10, 10,  8,  4,  5,  7,
#         7,  2,  2,  2,  2, 13,  4,  6,  7,  3,  2,  1,  4,  4,  8,  5, 12,
#         9, 11,  2,  2,  8, 11,  1,  8,  5, 12, 10, 13,  6, 13,  9, 11,  6,
#         8,  3, 10,  1,  4,  5,  6,  9,  8,  9,  8,  6,  2, 12, 12, 12,  8,
#         2,  6,  8, 12,  6,  1,  1,  9, 13,  2,  2,  2,  2,  1, 12, 10,  2,
#        12, 12,  0, 11, 12, 11,  6,  6,  7, 11, 13, 11, 11,  1,  4, 12,  4,
#         3, 12,  3,  2, 10,  6,  3,  2, 13, 13, 13,  1, 12,  9,  9,  9,  1,
#        11,  2,  6,  2,  2, 11, 11,  8,  8,  4, 13,  3,  9,  3,  2,  2, 12,
#        13, 12,  6,  0,  2,  3,  7,  6,  0,  1,  2,  0,  6, 13,  7,  6,  2,
#         1,  7,  7, 12,  2,  3,  4,  6,  0,  1, 12,  2,  5,  2,  7, 12,  0,
#        13, 11,  7,  7,  1, 12, 13,  2, 11,  1, 13,  6,  4,  9,  6, 12,  0,
#         0,  7, 12, 12,  0, 13,  3, 13,  0, 13, 11,  7,  1,  7,  5,  5, 10,
#         4,  0,  6,  4,  4,  8, 11,  4,  0,  3,  6,  4, 11,  4,  5,  4,  4,
#         2,  9,  3,  6,  8,  6,  0,  8, 11,  1,  0,  6,  8,  1,  6,  1, 11,
#         0, 13,  2,  0, 12,  7, 13,  3, 13, 11,  6, 12,  6,  6,  0,  0,  6,
#         9,  1,  4,  1, 11, 10,  4,  7,  1, 11, 13,  0,  1,  1,  3,  7,  6,
#        12,  0,  0, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12,  6, 12,
#         0, 12, 12, 12, 12, 13,  3,  4,  7,  1,  0,  5,  1,  5, 13,  5,  5,
#         5,  9,  5,  3,  5,  5,  5,  1,  3,  8,  8,  3,  9,  8,  8,  8,  8,
#         8,  8,  8,  9,  8,  8,  8,  8,  8,  7, 13, 13,  6,  6,  6,  5,  0,
#         3,  3,  6, 13, 13,  3,  2,  3,  3,  3,  2,  3,  3,  9,  5,  1,  4,
#         4,  2,  8,  5, 13,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4,  4,
#        11,  2, 12,  3,  2, 10,  6,  9,  1,  6,  2,  5,  2,  2,  8,  2,  1,
#         2, 13, 13,  9,  1,  1, 11,  4,  4,  5,  2,  9,  5,  5,  3,  0,  5,
#         6, 11, 11,  9, 13, 13, 13, 13, 13,  9, 13, 13, 13, 13, 13,  7, 13,
#         3, 13,  1,  6, 13,  7, 13, 13, 11,  1,  3,  9,  9,  5,  1,  1,  9,
#         0,  5,  9,  9,  9,  9,  9,  9,  9,  2,  9,  3,  5,  0,  9,  9,  9,
#         9,  9,  9, 10,  0, 10, 12,  3,  1, 10, 10, 10, 12, 10, 10, 10, 10,
#         0, 10, 10,  9, 10,  4, 10, 10, 10, 10, 10,  0,  9,  0,  1,  6,  1,
#         3,  9,  0,  6,  6,  9,  0,  0,  0,  5,  8,  0,  0,  0,  6,  0, 13,
#         6,  1,  6,  6,  2,  6,  3,  1,  6,  6,  1,  6,  3,  1,  3,  6,  6,
#         6,  6,  6,  3,  6,  7,  7,  3,  7,  5,  8,  7,  0,  7,  9,  3, 13,
#         6,  9,  7, 13,  7,  6,  8, 13,  7,  7,  4,  1,  1,  9,  5,  1,  9,
#         1,  1,  0,  1,  1,  1,  1,  9,  1, 13,  6,  2,  5])

# %%
cat_names = []
for cat,cid in sorted(cat2id.items(),key=lambda x:x[1]):
    cat_names.append(cat)
print(classification_report(y_test, y_test_predictions, target_names=cat_names))
# Out:
#                        precision    recall  f1-score   support
#
#  Science & Technology       0.36      0.40      0.38        43
#       News & Politics       0.36      0.57      0.44        37
#         Entertainment       0.69      0.67      0.68        49
#      Film & Animation       0.41      0.37      0.39        46
#        Pets & Animals       0.70      0.71      0.70        45
# Nonprofits & Activism       0.40      0.37      0.38        38
#       Travel & Events       0.42      0.52      0.46        54
#                 Music       0.55      0.45      0.49        40
#                Comedy       0.62      0.61      0.61        38
#                Sports       0.51      0.47      0.49        53
#         Howto & Style       0.97      0.75      0.85        40
#             Education       0.62      0.44      0.51        41
#      Autos & Vehicles       0.80      0.78      0.79        51
#                Gaming       0.58      0.62      0.60        50
#
#              accuracy                           0.56       625
#             macro avg       0.57      0.55      0.56       625
#          weighted avg       0.57      0.56      0.56       625

# %%
# what would a simple baseline be? How about most common category from before (Gaming)?
# we should *definitely* be doing better than this! Otherwise the model is not helping at all
baseline_predictions = [cat2id['Gaming']] * len(y_test)
baseline_accuracy = compute_accuracy(baseline_predictions,y_train)
print("Accuracy:",baseline_accuracy)
# Out:
# Accuracy: 0.0848

# %%
# trying a different model...
# how about a random forest classifier?
# %time
model = RandomForestClassifier()
model.fit(X_train,y_train)

y_train_predictions = model.predict(X_train)
print("Train accuracy was:",compute_accuracy(y_train_predictions,y_train))
y_test_predictions = model.predict(X_test)
print("Test accuracy was:",compute_accuracy(y_test_predictions,y_test))
# Out:
# CPU times: user 4 µs, sys: 1 µs, total: 5 µs
# Wall time: 10.3 µs
# Train accuracy was: 1.0
# Test accuracy was: 0.6224

# %%
cat_names = []
for cat,cid in sorted(cat2id.items(),key=lambda x:x[1]):
    cat_names.append(cat)
print(classification_report(y_test, y_test_predictions, target_names=cat_names))
# Out:
#                        precision    recall  f1-score   support
#
#  Science & Technology       0.36      0.37      0.37        43
#       News & Politics       0.25      0.49      0.33        37
#         Entertainment       0.83      0.71      0.77        49
#      Film & Animation       0.54      0.61      0.57        46
#        Pets & Animals       0.83      0.87      0.85        45
# Nonprofits & Activism       0.62      0.39      0.48        38
#       Travel & Events       0.55      0.48      0.51        54
#                 Music       0.72      0.57      0.64        40
#                Comedy       0.64      0.55      0.59        38
#                Sports       0.63      0.51      0.56        53
#         Howto & Style       0.70      0.82      0.76        40
#             Education       0.73      0.66      0.69        41
#      Autos & Vehicles       0.79      0.86      0.82        51
#                Gaming       0.74      0.74      0.74        50
#
#              accuracy                           0.62       625
#             macro avg       0.64      0.62      0.62       625
#          weighted avg       0.64      0.62      0.63       625

# %% [markdown]
# ## Zero-shot classification using Gemini models

# %% [markdown]
# Before you run the following cell, store your API key in a Colab Secret named `GOOGLE_API_KEY`. If you don't already have an API key or you aren't sure how to create a Colab Secret, see [Authentication](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Authentication.ipynb) for an example. Only the steps "Create an API Key" and "Add your key to Colab Secrets" from that page are needed here.

# %%
from google.colab import userdata

GOOGLE_API_KEY = userdata.get('GOOGLE_API_KEY')

# %%
from google import genai
from google.genai import types

client = genai.Client(api_key=GOOGLE_API_KEY)

# %%
MODEL_ID = "gemini-2.0-flash-lite" # @param ["gemini-2.5-flash-preview-05-20", "gemini-2.5-pro-preview-05-06", "gemini-2.0-flash-lite"] {"allow-input":true, isTemplate: true}

# %%
from IPython.display import Markdown

response = client.models.generate_content(
    model=MODEL_ID,
    contents="What's the largest planet in our solar system?"
)

Markdown(response.text)
# Out:
# The largest planet in our solar system is **Jupiter**.

# %%
set(training_categories)
# Out:
# {'Autos & Vehicles',
#  'Comedy',
#  'Education',
#  'Entertainment',
#  'Film & Animation',
#  'Gaming',
#  'Howto & Style',
#  'Music',
#  'News & Politics',
#  'Nonprofits & Activism',
#  'Pets & Animals',
#  'Science & Technology',
#  'Sports',
#  'Travel & Events'}

# %%
response = client.models.generate_content(
    model=MODEL_ID,
    contents="""Classify the following text as one of the following categories. Output only the category, with no Markdown formatting. Categories: {'Music', 'Entertainment', 'Autos & Vehicles', 'Travel & Events', 'Nonprofits & Activism', 'Howto & Style', 'Comedy', 'Pets & Animals', 'Science & Technology', 'Gaming', 'Sports', 'Film & Animation', 'News & Politics', 'Education'}
    Text: I like my dog
"""
)

# %%
Markdown(response.text)
# Out:
# Pets & Animals

# %%
response.text
# Out:
# 'Pets & Animals\n'

# %% [markdown]
# When making request to the Gemini API, we need to be aware of API limits. Gemini API limits can be found here: https://ai.google.dev/gemini-api/docs/rate-limits

# %% [markdown]
# ### Attempt no. 1: Make one request for each example

# %% [markdown]
# Let's try making one request per example.

# %%
from tqdm import tqdm
import time

# %%
gemini_classifications = []

for test_example in tqdm(test_data["Text"]):
  response = client.models.generate_content(
      model=MODEL_ID,
      contents="""Classify the following text as one of the following categories. Output only the category, with no Markdown formatting. Categories: {'Music', 'Entertainment', 'Autos & Vehicles', 'Travel & Events', 'Nonprofits & Activism', 'Howto & Style', 'Comedy', 'Pets & Animals', 'Science & Technology', 'Gaming', 'Sports', 'Film & Animation', 'News & Politics', 'Education'}
      Text: """ + test_example
      )
  time.sleep(5)
  gemini_classifications.append(response.text)
# Out:
#  11%|█         | 68/625 [07:05<58:02,  6.25s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-251-55ef3a667468> in <cell line: 0>()
#       7       Text: """ + test_example
#       8       )
# ----> 9   time.sleep(5)
#      10   gemini_classifications.append(response.text)
#
# KeyboardInterrupt:

# %% [markdown]
# When running the above without time.sleep(5), I hit the rate limit. (Error 429)
#
# When running the above with time.sleep(5), the requests works but takes more than an hour!
#
# Let's try something else.

# %% [markdown]
# ### Attempt no. 2: Requesting all examples in one go, with JSON schema in the text prompt

# %%
import json

# %%
prompt_parts = [
        "You are a tweet classifier. Classify the following tweets into one of these categories: " + ", ".join(test_categories) + ".\n",
        "Return the classifications as a JSON array of objects, where each object has 'ID' and 'category'.\n",
        "Example:\n",
        json.dumps([
            {"ID": "T1", "text": "I love my dog!", "category": "Pets & Animals"},
            {"ID": "T2", "text": "What kind of murderer has moral fibre? A cereal killer.", "category": "Comedy"}
        ]),
        "\n\nClassify the following:\n",
        test_data[["ID","Text"]].to_json(orient = 'records')
    ]

generation_config = {
    "response_mime_type": "application/json",
    }

response_json = client.models.generate_content(
      model=MODEL_ID,
      contents=prompt_parts,
      config = generation_config
      )

# %%
json.loads(response_json.text)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-27-423b9d02668f> in <cell line: 0>()
# ----> 1 json.loads(response_json.text)
#
# /usr/lib/python3.11/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#     348         cls = JSONDecoder
#
# /usr/lib/python3.11/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# /usr/lib/python3.11/json/decoder.py in raw_decode(self, s, idx)
#     351         """
#     352         try:
# --> 353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
#     355             raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Expecting ',' delimiter: line 831 column 15 (char 14511)

# %% [markdown]
# I got a JSONDecodeError, indicating that the model response could not be parsed as valid JSON. It looks like simply asking the model politely to output valid JSON does not work that well!

# %% [markdown]
# ### Attempt no. 3: Requesting all examples in one go, with constrained generation

# %% [markdown]
# Let's try something else. This time we'll define a JSON schema. This should force the model to output data that conforms to this schema. Read more on this approach here:
#
# https://ai.google.dev/gemini-api/docs/structured-output

# %%
from pydantic import BaseModel

class TweetCategories(BaseModel):
    ID: str
    category: str

prompt_parts = [
        "You are a tweet classifier. Classify the following tweets into one of these categories: " + ", ".join(test_categories) + ".\n",
        "Classify the following:\n",
        test_data[["ID","Text"]].to_json(orient = 'records')
    ]

generation_config = {
    "response_mime_type": "application/json",
    "response_schema": list[TweetCategories],
    }

response_constrained_json = client.models.generate_content(
      model=MODEL_ID,
      contents=prompt_parts,
      config=generation_config
      )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-133-cb611446a608> in <cell line: 0>()
#      16     }
#      17
# ---> 18 response_constrained_json = client.models.generate_content(
#      19       model=MODEL_ID,
#      20       contents=prompt_parts,
#
# /usr/local/lib/python3.11/dist-packages/google/genai/models.py in generate_content(self, model, contents, config)
#    5628     while remaining_remote_calls_afc > 0:
#    5629       i += 1
# -> 5630       response = self._generate_content(
#    5631           model=model, contents=contents, config=parsed_config
#    5632       )
#
# /usr/local/lib/python3.11/dist-packages/google/genai/models.py in _generate_content(self, model, contents, config)
#    4591     request_dict = _common.encode_unserializable_types(request_dict)
#    4592
# -> 4593     response_dict = self._api_client.request(
#    4594         'post', path, request_dict, http_options
#    4595     )
#
# /usr/local/lib/python3.11/dist-packages/google/genai/_api_client.py in request(self, http_method, path, request_dict, http_options)
#     753         http_method, path, request_dict, http_options
#     754     )
# --> 755     response = self._request(http_request, stream=False)
#     756     json_response = response.json
#     757     if not json_response:
#
# /usr/local/lib/python3.11/dist-packages/google/genai/_api_client.py in _request(self, http_request, stream)
#     675       )
#     676     else:
# --> 677       response = self._httpx_client.request(
#     678           method=http_request.method,
#     679           url=http_request.url,
#
# /usr/local/lib/python3.11/dist-packages/httpx/_client.py in request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     823             extensions=extensions,
#     824         )
# --> 825         return self.send(request, auth=auth, follow_redirects=follow_redirects)
#     826
#     827     @contextmanager
#
# /usr/local/lib/python3.11/dist-packages/httpx/_client.py in send(self, request, stream, auth, follow_redirects)
#     912         auth = self._build_request_auth(request, auth)
#     913
# --> 914         response = self._send_handling_auth(
#     915             request,
#     916             auth=auth,
#
# /usr/local/lib/python3.11/dist-packages/httpx/_client.py in _send_handling_auth(self, request, auth, follow_redirects, history)
#     940
#     941             while True:
# --> 942                 response = self._send_handling_redirects(
#     943                     request,
#     944                     follow_redirects=follow_redirects,
#
# /usr/local/lib/python3.11/dist-packages/httpx/_client.py in _send_handling_redirects(self, request, follow_redirects, history)
#     977                 hook(request)
#     978
# --> 979             response = self._send_single_request(request)
#     980             try:
#     981                 for hook in self._event_hooks["response"]:
#
# /usr/local/lib/python3.11/dist-packages/httpx/_client.py in _send_single_request(self, request)
#    1012
#    1013         with request_context(request=request):
# -> 1014             response = transport.handle_request(request)
#    1015
#    1016         assert isinstance(response.stream, SyncByteStream)
#
# /usr/local/lib/python3.11/dist-packages/httpx/_transports/default.py in handle_request(self, request)
#     248         )
#     249         with map_httpcore_exceptions():
# --> 250             resp = self._pool.handle_request(req)
#     251
#     252         assert isinstance(resp.stream, typing.Iterable)
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_sync/connection_pool.py in handle_request(self, request)
#     254
#     255             self._close_connections(closing)
# --> 256             raise exc from None
#     257
#     258         # Return the response. Note that in this case we still have to manage
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_sync/connection_pool.py in handle_request(self, request)
#     234                 try:
#     235                     # Send the request on the assigned connection.
# --> 236                     response = connection.handle_request(
#     237                         pool_request.request
#     238                     )
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_sync/connection.py in handle_request(self, request)
#     101             raise exc
#     102
# --> 103         return self._connection.handle_request(request)
#     104
#     105     def _connect(self, request: Request) -> NetworkStream:
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_sync/http11.py in handle_request(self, request)
#     134                 with Trace("response_closed", logger, request) as trace:
#     135                     self._response_closed()
# --> 136             raise exc
#     137
#     138     # Sending the request...
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_sync/http11.py in handle_request(self, request)
#     104                     headers,
#     105                     trailing_data,
# --> 106                 ) = self._receive_response_headers(**kwargs)
#     107                 trace.return_value = (
#     108                     http_version,
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_sync/http11.py in _receive_response_headers(self, request)
#     175
#     176         while True:
# --> 177             event = self._receive_event(timeout=timeout)
#     178             if isinstance(event, h11.Response):
#     179                 break
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_sync/http11.py in _receive_event(self, timeout)
#     215
#     216             if event is h11.NEED_DATA:
# --> 217                 data = self._network_stream.read(
#     218                     self.READ_NUM_BYTES, timeout=timeout
#     219                 )
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_backends/sync.py in read(self, max_bytes, timeout)
#     126         with map_exceptions(exc_map):
#     127             self._sock.settimeout(timeout)
# --> 128             return self._sock.recv(max_bytes)
#     129
#     130     def write(self, buffer: bytes, timeout: float | None = None) -> None:
#
# /usr/lib/python3.11/ssl.py in recv(self, buflen, flags)
#    1293                     "non-zero flags not allowed in calls to recv() on %s" %
#    1294                     self.__class__)
# -> 1295             return self.read(buflen)
#    1296         else:
#    1297             return super().recv(buflen, flags)
#
# /usr/lib/python3.11/ssl.py in read(self, len, buffer)
#    1166                 return self._sslobj.read(len, buffer)
#    1167             else:
# -> 1168                 return self._sslobj.read(len)
#    1169         except SSLError as x:
#    1170             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
gemini_categories: list[TweetCategories] = response_constrained_json.parsed

# %%
response_constrained_json.parsed is None
# Out:
# True

# %% [markdown]
# Unfortunately, for me this did not work either. The call to .parsed returns None instead of a list of TweetCategories, indicating that the output could not be parsed as valid JSON. Inspecting the output using response_constrained_json.text shows that the output is cut off after about 200 examples. Apparently we requested too much data in one go.

# %% [markdown]
# ### Attempt no. 4: Requesting classification for 100 tweets at a time

# %% [markdown]
# In this next attempt, we'll use the same approach as before, with structured generation, but only request 100 examples at a time.

# %%
json_request_batches = []

for start in range(0, len(test_data), 100):
  json_request_batches.append(
      test_data.loc[start:start+100,["ID","Text"]].to_json(orient = 'records')
      )

# %%
len(json_request_batches)
# Out:
# 7

# %% [markdown]
# We've now split our data into 7 batches. (6 of 100 examples each and one batch of 30)

# %%
generation_config = {
    "response_mime_type": "application/json",
    "response_schema": list[TweetCategories],
    }

json_batch_results = []

for json_batch in tqdm(json_request_batches):
  prompt = [
        "You are a tweet classifier. Classify the following tweets into one of these categories: " + ", ".join(test_categories) + ".\n",
        "Classify the following:\n",
        json_batch
    ]

  response_constrained_json = client.models.generate_content(
      model=MODEL_ID,
      contents=prompt,
      config=generation_config
      )
  json_batch_results.append(response_constrained_json)
  time.sleep(5)
# Out:
#  71%|███████▏  | 5/7 [02:04<00:49, 24.95s/it]
# ---------------------------------------------------------------------------
# ServerError                               Traceback (most recent call last)
# <ipython-input-147-26f6196c3f9b> in <cell line: 0>()
#      13     ]
#      14
# ---> 15   response_constrained_json = client.models.generate_content(
#      16       model=MODEL_ID,
#      17       contents=prompt,
#
# /usr/local/lib/python3.11/dist-packages/google/genai/models.py in generate_content(self, model, contents, config)
#    5628     while remaining_remote_calls_afc > 0:
#    5629       i += 1
# -> 5630       response = self._generate_content(
#    5631           model=model, contents=contents, config=parsed_config
#    5632       )
#
# /usr/local/lib/python3.11/dist-packages/google/genai/models.py in _generate_content(self, model, contents, config)
#    4591     request_dict = _common.encode_unserializable_types(request_dict)
#    4592
# -> 4593     response_dict = self._api_client.request(
#    4594         'post', path, request_dict, http_options
#    4595     )
#
# /usr/local/lib/python3.11/dist-packages/google/genai/_api_client.py in request(self, http_method, path, request_dict, http_options)
#     753         http_method, path, request_dict, http_options
#     754     )
# --> 755     response = self._request(http_request, stream=False)
#     756     json_response = response.json
#     757     if not json_response:
#
# /usr/local/lib/python3.11/dist-packages/google/genai/_api_client.py in _request(self, http_request, stream)
#     682           timeout=http_request.timeout,
#     683       )
# --> 684       errors.APIError.raise_for_response(response)
#     685       return HttpResponse(
#     686           response.headers, response if stream else [response.text]
#
# /usr/local/lib/python3.11/dist-packages/google/genai/errors.py in raise_for_response(cls, response)
#     101       raise ClientError(status_code, response_json, response)
#     102     elif 500 <= status_code < 600:
# --> 103       raise ServerError(status_code, response_json, response)
#     104     else:
#     105       raise cls(status_code, response_json, response)
#
# ServerError: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}

# %% [markdown]
# When running this I get an error, ServerError: 503 UNAVAILABLE. The model is overloaded. Please try again later.
# Clearly not every request succeeds. Let's try again with proper exception handling, waiting five seconds if the request fails.

# %%
generation_config = {
    "response_mime_type": "application/json",
    "response_schema": list[TweetCategories],
    }

json_batch_results = []

for json_batch in tqdm(json_request_batches):
  prompt = [
        "You are a tweet classifier. Classify the following tweets into one of these categories: " + ", ".join(test_categories) + ".\n",
        "Classify the following:\n",
        json_batch
    ]

  retries = 3 # Number of retries

  for attempt in range(retries):
      try:
          response_constrained_json = client.models.generate_content(
              model=MODEL_ID,
              contents=prompt,
              config=generation_config
              )
          json_batch_results.append(response_constrained_json)
          break # Success, exit retry loop
      except errors.ServerError as e:
        time.sleep(5) # Wait for 5 seconds
      except Exception as e:
          raise e # Re-raise other exceptions

  time.sleep(5) # Keep a small delay between batches as well
# Out:
# 100%|██████████| 7/7 [02:56<00:00, 25.28s/it]

# %%
parsed_results = [result_batch.parsed for result_batch in json_batch_results]

# %%
for p in parsed_results:
  print(p is None)
# Out:
# False
# False
# False
# False
# False
# False
# False

# %%
json_batch_results[0].text
# Out:
# '[\n  {\n    "ID": "45108992991784550",\n    "category": "Pets & Animals"\n  },\n  {\n    "ID": "45034300968799027",\n    "category": "Music"\n  },\n  {\n    "ID": "45077420496768205",\n    "category": "News & Politics"\n  },\n  {\n    "ID": "45056046598311116",\n    "category": "Autos & Vehicles"\n  },\n  {\n    "ID": "45134816305232691",\n    "category": "Science & Technology"\n  },\n  {\n    "ID": "45072223200464896",\n    "category": "Autos & Vehicles"\n  },\n  {\n    "ID": "45073984987243724",\n    "category": "Gaming"\n  },\n  {\n    "ID": "45083134973446553",\n    "category": "Film & Animation"\n  },\n  {\n    "ID": "45101698759068467",\n    "category": "Film & Animation"\n  },\n  {\n    "ID": "45142325339580006",\n    "category": "Film & Animation"\n  },\n  {\n    "ID": "45188110355372441",\n    "category": "Comedy"\n  },\n  {\n    "ID": "45102066684672000",\n    "category": "Education"\n  },\n  {\n    "ID": "45142569757194649",\n    "category": "Education"\n  },\n  {\n    "ID": "45104383590978355",\n    "category": "Comedy"\n  },\n  {\n    "ID": "45106677076631552",\n    "category": "Autos & Vehicles"\n  },\n  {\n    "ID": "45110062154306355",\n    "category": "Pets & Animals"\n  },\n  {\n    "ID": "45125438057493299",\n    "category": "News & Politics"\n  },\n  {\n    "ID": "45158666905389465",\n    "category": "Autos & Vehicles"\n  },\n  {\n    "ID": "45134131216424140",\n    "category": "Travel & Events"\n  },\n  {\n    "ID": "45159364845961625",\n    "category": "Pets & Animals"\n  },\n  {\n    "ID": "45163788248758272",\n    "category": "Education"\n  },\n  {\n    "ID": "45172996627145932",\n    "category": "Science & Technology"\n  },\n  {\n    "ID": "45181576762621952",\n    "category": "Comedy"\n  },\n  {\n    "ID": "45367798751560089",\n    "category": "News & Politics"\n  },\n  {\n    "ID": "45189512585441280",\n    "category": "Comedy"\n  },\n  {\n    "ID": "45207464265700966",\n    "category": "Music"\n  },\n  {\n    "ID": "45201338595019980",\n    "category": "Travel & Events"\n  },\n  {\n    "ID": "45203328715890278",\n    "category": "Comedy"\n  },\n  {\n    "ID": "45208197339403059",\n    "category": "Autos & Vehicles"\n  },\n  {\n    "ID": "45210195771748761",\n    "category": "Comedy"\n  },\n  {\n    "ID": "45213137443083059",\n    "category": "Film & Animation"\n  },\n  {\n    "ID": "45270220465137254",\n    "category": "Comedy"\n  },\n  {\n    "ID": "46221501982941184",\n    "category": "Gaming"\n  },\n  {\n    "ID": "46202551070152294",\n    "category": "Travel & Events"\n  },\n  {\n    "ID": "46207827326325555",\n    "category": "Comedy"\n  },\n  {\n    "ID": "46224222616134860",\n    "category": "Travel & Events"\n  },\n  {\n    "ID": "46225898619326873",\n    "category": "Comedy"\n  },\n  {\n    "ID": "46246718525263872",\n    "category": "Comedy"\n  },\n  {\n    "ID": "46280146189916979",\n    "category": "Sports"\n  },\n  {\n    "ID": "46228184179462144",\n    "category": "Travel & Events"\n  },\n  {\n    "ID": "46232495967975014",\n    "category": "Education"\n  },\n  {\n    "ID": "46234084439021568",\n    "category": "Education"\n  },\n  {\n    "ID": "46239269820566732",\n    "category": "Autos & Vehicles"\n  },\n  {\n    "ID": "46283550706054758",\n    "category": "Education"\n  },\n  {\n    "ID": "46244945863916339",\n    "category": "Sports"\n  },\n  {\n    "ID": "46258394239966412",\n    "category": "Education"\n  },\n  {\n    "ID": "46263963158736076",\n    "category": "Travel & Events"\n  },\n  {\n    "ID": "46274087529954508",\n    "category": "Sports"\n  },\n  {\n    "ID": "46281588473909657",\n    "category": "Pets & Animals"\n  },\n  {\n    "ID": "46297551402240409",\n    "category": "News & Politics"\n  },\n  {\n    "ID": "45061244239008563",\n    "category": "Travel & Events"\n  },\n  {\n    "ID": "45114180238537113",\n    "category": "Travel & Events"\n  },\n  {\n    "ID": "46295199094368256",\n    "category": "Travel & Events"\n  },\n  {\n    "ID": "46302800300264652",\n    "c ...

# %%
for p in parsed_results:
  print(len(p))
# Out:
# 101
# 101
# 101
# 100
# 101
# 101
# 25

# %%
for batch in json_request_batches:
  print(len(p))
# Out:
# 25
# 25
# 25
# 25
# 25
# 25
# 25

# %% [markdown]
# Interestingly, the length of each result batch (in parsed_results) does not match exactly the length of the request batches (in json_request_batches).
#
# We could investigate this further: it looks like the model may sometimes include classifications for tweets that weren't in the original request (hallucinations), or sometimes omit tweets from the original request.
#
# Now let's look up each tweet ID in our results, implementing some fallback handling for tweets in the request that weren't found in the results.

# %%
# look up the tweet ID in the results
# as a fallback, if the tweet ID is not found, return the most common category
# note that we could return None instead, in this case, the call to classification_report would fail (it cannot handle missing data)
# replacing with the most common value is a common form of data imputation to handle missing values
def find_label(tweet_id):
  for result_batch in parsed_results:
    for result in result_batch:
      if result.ID == str(tweet_id):
        return result.category
  return 'Gaming'

# %%
test_predictions_gemini = []

for tweet_id in test_data["ID"].tolist():
  test_predictions_gemini.append(find_label(tweet_id))

# %%
len(test_predictions_gemini)
# Out:
# 625

# %%
len(test_categories)
# Out:
# 625

# %%
print(classification_report(test_categories, test_predictions_gemini))
# Out:
#                        precision    recall  f1-score   support
#
#      Autos & Vehicles       0.92      0.96      0.94        51
#                Comedy       0.73      0.84      0.78        38
#             Education       0.80      0.90      0.85        41
#         Entertainment       0.79      0.63      0.70        49
#      Film & Animation       0.80      0.80      0.80        46
#                Gaming       0.92      0.90      0.91        50
#         Howto & Style       0.97      0.80      0.88        40
#                 Music       0.82      0.82      0.82        40
#       News & Politics       0.54      0.84      0.66        37
# Nonprofits & Activism       0.88      0.74      0.80        38
#        Pets & Animals       0.91      0.96      0.93        45
#              Religion       0.00      0.00      0.00         0
#  Science & Technology       0.81      0.81      0.81        43
#                Sports       0.93      0.75      0.83        53
#       Travel & Events       0.92      0.89      0.91        54
#
#              accuracy                           0.83       625
#             macro avg       0.78      0.78      0.78       625
#          weighted avg       0.85      0.83      0.84       625
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# The results are much better than the Random Forest classifier, which got an F1 score of 0.62.
#
# But something odd is happening here: I am getting an error message, "UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples" This seems to be about the label "Religion"

# %%
# Let's look at the true category labels from the test data
set(test_categories)
# Out:
# {'Autos & Vehicles',
#  'Comedy',
#  'Education',
#  'Entertainment',
#  'Film & Animation',
#  'Gaming',
#  'Howto & Style',
#  'Music',
#  'News & Politics',
#  'Nonprofits & Activism',
#  'Pets & Animals',
#  'Science & Technology',
#  'Sports',
#  'Travel & Events'}

# %%
# Let's look at the predicted category labels from the test data
set(test_predictions_gemini)
# Out:
# {'Autos & Vehicles',
#  'Comedy',
#  'Education',
#  'Entertainment',
#  'Film & Animation',
#  'Gaming',
#  'Howto & Style',
#  'Music',
#  'News & Politics',
#  'Nonprofits & Activism',
#  'Pets & Animals',
#  'Religion',
#  'Science & Technology',
#  'Sports',
#  'Travel & Events'}

# %% [markdown]
# My output to the last call includes a 15th category, Religion. Gemini has made up this category! Let's print the tweet.

# %%
for tweet_id in test_data["ID"].tolist():
  cat = find_label(tweet_id)
  if cat == "Religion":
    print(test_data.loc[test_data.ID == tweet_id, 'Text'].iloc[0])
# Out:
# Join us on http://t.co/da82RRNXWA! #Christian #Single #Jesus #Bible #Prayer #Discussions #Easter #Movies #Football

# %% [markdown]
# Fair enough, this tweet is about religion, or at least it uses hashtags about religion. Maybe you can prevent Gemini from inventing categories in the reponse by changing the prompt? Try and see for yourself!
